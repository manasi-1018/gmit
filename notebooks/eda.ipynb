# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_css("..\source_data\med-insurance.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\admin\AppData\Local\Temp\ipykernel_10820\9793278.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_css("..\source_data\med-insurance.csv")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_css("..\source_data\med-insurance.csv")
#
# AttributeError: module 'pandas' has no attribute 'read_css'

# %%
df = pd.read_csv("..\source_data\med-insurance.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\admin\AppData\Local\Temp\ipykernel_10820\2038011568.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv("..\source_data\med-insurance.csv")

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
df.smoker.replace(("yes","no"),(1,0),inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_10820\2190621808.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.smoker.replace(("yes","no"),(1,0),inplace=True)

# %%
df.head()
# Out:
#    age     sex   bmi  children  smoker     region  expenses
# 0   19  female  27.9         0       1  southwest  16884.92
# 1   18    male  33.8         1       0  southeast   1725.55
# 2   28    male  33.0         3       0  southeast   4449.46
# 3   33    male  22.7         0       0  northwest  21984.47
# 4   32    male  28.9         0       0  northwest   3866.86

# %%
df.sex.replace(("male","female"),(1,0),inplace=True)

# %%
df.head()
# Out:
#    age  sex   bmi  children  smoker     region  expenses
# 0   19    0  27.9         0       1  southwest  16884.92
# 1   18    1  33.8         1       0  southeast   1725.55
# 2   28    1  33.0         3       0  southeast   4449.46
# 3   33    1  22.7         0       0  northwest  21984.47
# 4   32    1  28.9         0       0  northwest   3866.86

# %%
df['region']=[0 if i=='southwest'else
               1 if i=='southeast' else
               2 if i=='northwest' else
               3 for i in df['region']]

# %%
df.head()
# Out:
#    age  sex   bmi  children  smoker  region  expenses
# 0   19    0  27.9         0       1       3  16884.92
# 1   18    1  33.8         1       0       3   1725.55
# 2   28    1  33.0         3       0       3   4449.46
# 3   33    1  22.7         0       0       3  21984.47
# 4   32    1  28.9         0       0       3   3866.86

# %%
df.head()
# Out:
#    age  sex   bmi  children  smoker  region  expenses
# 0   19    0  27.9         0       1       3  16884.92
# 1   18    1  33.8         1       0       3   1725.55
# 2   28    1  33.0         3       0       3   4449.46
# 3   33    1  22.7         0       0       3  21984.47
# 4   32    1  28.9         0       0       3   3866.86

# %%
df['region']=[0 if i=='southwest'else
             1 if i=='southeast' else
               2 if i=='northwest' else
               3 for i in df['region']]
df.head()
# Out:
#    age  sex   bmi  children  smoker  region  expenses
# 0   19    0  27.9         0       1       3  16884.92
# 1   18    1  33.8         1       0       3   1725.55
# 2   28    1  33.0         3       0       3   4449.46
# 3   33    1  22.7         0       0       3  21984.47
# 4   32    1  28.9         0       0       3   3866.86

# %%
df['region']=[0 if i=='southwest'else
              1 if i=='southeast' else
              2 if i=='northwest' else
              3 for i in df['region']]

# %%
df.head()
# Out:
#    age  sex   bmi  children  smoker  region  expenses
# 0   19    0  27.9         0       1       3  16884.92
# 1   18    1  33.8         1       0       3   1725.55
# 2   28    1  33.0         3       0       3   4449.46
# 3   33    1  22.7         0       0       3  21984.47
# 4   32    1  28.9         0       0       3   3866.86

# %%
df.to_csv('../data/raw/insurance.csv',mode='w',index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df.to_csv('../data/raw/insurance.csv',node='w',index=False)
#
# File c:\Users\admin\Desktop\GITMCA\.venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# TypeError: NDFrame.to_csv() got an unexpected keyword argument 'node'
